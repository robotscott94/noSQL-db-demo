# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo.uk_food

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db.establishments

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene": {"$eq": 20}}
results = establishments.find(query)

# Use count_documents to display the number of documents in the result
establishments.count_documents(query)
# Out:
# 41

# %%
# Display the first document in the results using pprint
pprint(results[0])
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('640a122f8262e151aa17f4fb'),
#  'geocode': {'latitude': Decimal128('50.769705'),
#              'longitude': Decimal128('0.27694')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(results)
df
# Out:
#                          _id   FHRSID  ChangesByServerID  \
# 0   640a122f8262e151aa17f4fb   110681                  0
# 1   640a122f8262e151aa17f880   612039                  0
# 2   640a122f8262e151aa17fb82   730933                  0
# 3   640a122f8262e151aa17fd7a   172953                  0
# 4   640a122f8262e151aa17fd81   172735                  0
# 5   640a122f8262e151aa18071d   512854                  0
# 6   640a122f8262e151aa18093f  1537089                  0
# 7   640a12308262e151aa181e6b   155648                  0
# 8   640a12308262e151aa1822af  1012883                  0
# 9   640a12308262e151aa182abf   644109                  0
# 10  640a12308262e151aa182b30   267034                  0
# 11  640a12308262e151aa1831e5   972876                  0
# 12  640a12308262e151aa183abf  1417416                  0
# 13  640a12308262e151aa1840c1  1384371                  0
# 14  640a12308262e151aa18441d   907216                  0
# 15  640a12308262e151aa18498f   710382                  0
# 16  640a12308262e151aa1849fd  1411729                  0
# 17  640a12308262e151aa184c5e  1060293                  0
# 18  640a12308262e151aa185245  1243155                  0
# 19  640a12308262e151aa1857ef  1210197                  0
# 20  640a12308262e151aa18580a   108663                  0
# 21  640a12308262e151aa185ae7  1107748                  0
# 22  640a12308262e151aa185b2f   570096                  0
# 23  640a12308262e151aa185c2b  1500698                  0
# 24  640a12308262e151aa185ce9  1318114                  0
# 25  640a12308262e151aa185cfe  1498084                  0
# 26  640a12308262e151aa185de3  1063454                  0
# 27  640a12308262e151aa185e64  1130121                  0
# 28  640a12308262e151aa1860a8   640363                  0
# 29  640a12308262e151aa1860f0   640816                  0
# 30  640a12308262e151aa18615e  1530599                  0
# 31  640a12308262e151aa186272   668674                  0
# 32  640a12308262e151aa18635e  1286585                  0
# 33  640a12308262e151aa18640c   971735                  0
# 34  640a12308262e151aa1865b8  1055935                  0
# 35  640a12308262e151aa18673f  1177878                  0
# 36  640a12308262e151aa18682e  1296829                  0
# 37  640a12318262e151aa186bbd   514573                  0
# 38  640a12318262e151aa186d9c   124507                  0
# 39  640a12318262e151aa186fc2   479001                  0
# 40  640a12318262e151aa1871b1   107710                  0
#
#    LocalAuthorityBusinessID  \
# 0                      4029
# 1                 1970/FOOD
# 2                 1698/FOOD
# 3              PI/000024532
# 4              PI/000023858
# 5             12/00816/BUTH
# 6           22/00224/RESTUN
# 7               EH/00006058
# 8          17/00110/MIXED/S
# 9                     41811
# 10           11/00102/MIXED
# 11          17/00059/FOOD/S
# 12              21/00350/CP
# 13           21/00062/MIXED
# 14                   132648
# 15             PI/000194267
# 16           21/00562/MIXED
# 17             PI/000206588
# 18                    75460
# 19                    75196
# 20                    38915
# 21            19/00222/FOOD
# 22                   178447
# 23                   201759
# 24                   200845
# 25            22/00797/FOOD
# 26            18/00285/FOOD
# 27            19/00249/FOOD
# 28            10/00269/FOOD
# 29         61130/0282/0/000
# 30            22/01037/FOOD
# 31             14/00082/COM
# 32            20/00532/FOOD
# 33             17/00076/COM
# 34            18/00198/FOOD
# 35                   347294
# 36                   347449
# 37                    44243
# 38              53022999151
# 39             12/00162/COM
# 40              38127001007
#
#                                          BusinessName  \
# 0                                 The Chase Rest Home
# 1                                          Brenalwood
# 2                                       Melrose Hotel
# 3                                       Golden Palace
# 4                                       Seaford Pizza
# 5                                    Ashby's Butchers
# 6                           South Sea Express Cuisine
# 7                                       Golden Palace
# 8                                      The Tulip Tree
# 9                                               F & S
# 10                                          Longhouse
# 11  Westview Playgroup Based At Downsview Comm Pri...
# 12                        Whatever The Weather Coffee
# 13                        Kings Restaurant (Oriental)
# 14                                            Xich Lo
# 15      Asian Supermarket Ltd: T/A Best Food Wine Ltd
# 16                                             Londis
# 17                                         Costcutter
# 18                                       La Simon Ltd
# 19                                     Caribiscus Ltd
# 20                              Kennedy Fried Chicken
# 21                                          Gah Shing
# 22                                     A1 News & Wine
# 23                                      Cakes & Bakes
# 24                        Sahajanand Catering Limited
# 25                                         Sisko Cafe
# 26                             Magazin Romanesc Diana
# 27                                      Bali Maamalas
# 28                                      Angels Bakery
# 29                            Nikkis Place Restaurant
# 30                                         Chicago 30
# 31                              Samui Thai Restaurant
# 32                            Pakhtoonkhwa Restaurant
# 33                                   New Happy Garden
# 34                                          Mummy Yum
# 35                                          Gospodina
# 36                                  Leo's Bar & Grill
# 37                                         Royal Ribs
# 38                      Great Hallingbury Manor Hotel
# 39                                   The Dog And Duck
# 40                                   Oriental Cottage
#
#                          BusinessType  BusinessTypeID  \
# 0                     Caring Premises               5
# 1                     Caring Premises               5
# 2   Hotel/bed & breakfast/guest house            7842
# 3             Restaurant/Cafe/Canteen               1
# 4              Takeaway/sandwich shop            7844
# 5                   Retailers - other            4613
# 6             Restaurant/Cafe/Canteen               1
# 7              Takeaway/sandwich shop            7844
# 8             Restaurant/Cafe/Canteen               1
# 9                   Retailers - other            4613
# 10            Restaurant/Cafe/Canteen               1
# 11            Other catering premises            7841
# 12                     Mobile caterer            7846
# 13             Takeaway/sandwich shop            7844
# 14            Restaurant/Cafe/Canteen               1
# 15                  Retailers - other            4613
# 16                  Retailers - other            4613
# 17                  Retailers - other            4613
# 18                  Retailers - other            4613
# 19            Restaurant/Cafe/Canteen               1
# 20             Takeaway/sandwich shop            7844
# 21             Takeaway/sandwich shop            7844
# 22                  Retailers - other            4613
# 23             Takeaway/sandwich shop            7844
# 24            Restaurant/Cafe/Canteen               1
# 25            Restaurant/Cafe/Canteen               1
# 26                  Retailers - other            4613
# 27            Restaurant/Cafe/Canteen               1
# 28            Other catering premises            7841
# 29            Restaurant/Cafe/Canteen               1
# 30             Takeaway/sandwich shop            7844
# 31            Restaurant/Cafe/Canteen               1
# 32            Restaurant/Cafe/Canteen               1
# 33             Takeaway/sandwich shop            7844
# 34             Takeaway/sandwich shop            7844
# 35                  Retailers - other            4613
# 36            Restaurant/Cafe/Canteen               1
# 37             Takeaway/sandwich shop            7844
# 38            Restaurant/Cafe/Canteen               1
# 39                  Pub/bar/nightclub            7843
# 40             Takeaway/sandwich shop            7844
#
#                           AddressLine1               AddressLine2  \
# 0                 5-6 Southfields Road                 Eastbourne
# 1                            Hall Lane         Walton-on-the-Naze
# 2                53 Marine Parade East             Clacton On Sea
# 3                       5 South Street                    Seaford
# 4                        4 High Street                    Seaford
# 5                 777 Southchurch Road            Southend-On-Sea
# 6                  33 Alexandra Street            Southend-on-sea
# 7                        7 London Road                   Rayleigh
# 8                        3 The Village              Chiddingstone
# 9                                                  81 Southernhay
# 10                      17 London Road                  Riverhead
# 11  Downsview Community Primary School               Beech Avenue
# 12                           EMR Erith                 Manor Road
# 13                       43 Kings Road                  Brentwood
# 14                     24 Station Lane                 Hornchurch
# 15                 2 - 6 Basildon Road
# 16                5 - 7 Cranley Parade          Beaconsfield Road
# 17                         2 The Slade
# 18                                               8 Porters Avenue
# 19                                             87 Longbridge Road
# 20                                              66 Station Parade
# 21                 5 High Street South                   East Ham
# 22                                                221 Ilford Lane
# 23                                                108 Ilford Lane
# 24                                                 149 Ley Street
# 25              151 - 153 Barking Road                   East Ham
# 26               221 High Street North                   East Ham
# 27              241B High Street North                 Manor Park
# 28                    333 Barking Road                   Plaistow
# 29                    282 Barking Road                   Plaistow
# 30                  369 Katherine Road                Forest Gate
# 31                          The Kinema            Chelmsford Road
# 32                     76 Green Street                Forest Gate
# 33                   23 Stortford Road                     Dunmow
# 34                    34 West Ham Lane                  Stratford
# 35                                      345 High Road Leytonstone
# 36                                                 32 Church Lane
# 37                                                  14 Hatch Lane
# 38             Great Hallingbury Manor             Tilekiln Green
# 39                     58 Lower Street                   Stansted
# 40                       1 Mercers Row             Saffron Walden
#
#          AddressLine3  ...                     LocalAuthorityWebSite  \
# 0         East Sussex  ...  http://www.eastbourne.gov.uk/foodratings
# 1               Essex  ...             http://www.tendringdc.gov.uk/
# 2               Essex  ...             http://www.tendringdc.gov.uk/
# 3         East Sussex  ...       http://www.lewes-eastbourne.gov.uk/
# 4         East Sussex  ...       http://www.lewes-eastbourne.gov.uk/
# 5               Essex  ...                http://www.southend.gov.uk
# 6               Essex  ...                http://www.southend.gov.uk
# 7               Essex  ...                http://www.rochford.gov.uk
# 8                KENT  ...              http://www.sevenoaks.gov.uk/
# 9            Basildon  ...                http://www.basildon.gov.uk
# 10               KENT  ...              http://www.sevenoaks.gov.uk/
# 11            Swanley  ...              http://www.sevenoaks.gov.uk/
# 12              Erith  ...                  http://www.bexley.gov.uk
# 13              Essex  ...              http://www.brentwood.gov.uk/
# 14                     ...                http://www.havering.gov.uk
# 15         Abbey Wood  ...          http://www.royalgreenwich.gov.uk
# 16         Mottingham  ...                 http://www.bromley.gov.uk
# 17          Plumstead  ...          http://www.royalgreenwich.gov.uk
# 18                     ...    http://www.lbbd.gov.uk/Pages/Home.aspx
# 19                     ...    http://www.lbbd.gov.uk/Pages/Home.aspx
# 20                     ...    http://www.lbbd.gov.uk/Pages/Home.aspx
# 21             London  ...                 https://www.newham.gov.uk
# 22                     ...              http://www.redbridge.gov.uk/
# 23                     ...              http://www.redbridge.gov.uk/
# 24                     ...              http://www.redbridge.gov.uk/
# 25             London  ...                 https://www.newham.gov.uk
# 26             London  ...                 https://www.newham.gov.uk
# 27             London  ...                 https://www.newham.gov.uk
# 28             London  ...                 https://www.newham.gov.uk
# 29             London  ...                 https://www.newham.gov.uk
# 30             London  ...                 https://www.newham.gov.uk
# 31             Dunmow  ...              http://www.uttlesford.gov.uk
# 32             London  ...                 https://www.newham.gov.uk
# 33                     ...              http://www.uttlesford.gov.uk
# 34             London  ...                 https://www.newham.gov.uk
# 35                     ...           http://www.walthamforest.gov.uk
# 36                     ...           http://www.walthamforest.gov.uk
# 37                     ...           http://www.walthamforest.gov.uk
# 38  Great Hallingbury  ...              http://www.uttlesford.gov.uk
# 39              Essex  ...              http://www.uttlesford.gov.uk
# 40              Essex  ...              http://www.uttlesford.gov.uk
#
#                   LocalAuthorityEmailAddress  \
# 0            Customerfirst@eastbourne.gov.uk
# 1                 fhsadmin@tendringdc.gov.uk
# 2                 fhsadmin@tendringdc.gov.uk
# 3        ehealth.ldc@lewes-eastbourne.gov.uk
# 4        ehealth.ldc@lewes-eastbourne.gov.uk
# 5        EnvironmentalHealth@southend.gov.uk
# 6        EnvironmentalHealth@southend.gov.uk
# 7           customerservices@rochford.gov.uk
# 8      environmental.health@sevenoaks.gov.uk
# 9                        ehs@basildon.gov.uk
# 10     environmental.health@sevenoaks.gov.uk
# 11     environmental.health@sevenoaks.gov.uk
# 12                 food.safety@bexley.gov.uk
# 13                envhealth@brentwood.gov.uk
# 14      environmental.health@havering.gov.uk
# 15              health@royalgreenwich.gov.uk
# 16                       food@bromley.gov.uk
# 17              health@royalgreenwich.gov.uk
# 18                    foodsafety@lbbd.gov.uk
# 19                    foodsafety@lbbd.gov.uk
# 20                    foodsafety@lbbd.gov.uk
# 21                        food@newham.gov.uk
# 22           themis.skouros@redbridge.gov.uk
# 23           themis.skouros@redbridge.gov.uk
# 24           themis.skouros@redbridge.gov.uk
# 25                        food@newham.gov.uk
# 26                        food@newham.gov.uk
# 27                        food@newham.gov.uk
# 28                        food@newham.gov.uk
# 29                        food@newham.gov.uk
# 30                        food@newham.gov.uk
# 31     environmentalhealth@uttlesford.gov.uk
# 32                        food@newham.gov.uk
# 33     environmentalhealth@uttlesford.gov.uk
# 34                        food@newham.gov.uk
# 35  environmentalhealth@walthamforest.gov.uk
# 36  environmentalhealth@walthamforest.gov.uk
# 37  environmentalhealth@walthamforest.gov.uk
# 38     environmentalhealth@uttlesford.gov.uk
# 39     environmentalhealth@uttlesford.gov.uk
# 40     environmentalhealth@uttlesford.gov.uk
#
#                                                scores SchemeType  \
# 0   {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 1   {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 2   {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 3   {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 4   {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 5   {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 6   {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 7   {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 8   {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 9   {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 10  {'Hygiene': 20, 'Structural': 25, 'ConfidenceI...       FHRS
# 11  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 12  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 13  {'Hygiene': 20, 'Structural': 25, 'ConfidenceI...       FHRS
# 14  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 15  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 16  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 17  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 18  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 19  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 20  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 21  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 22  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 23  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 24  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 25  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 26  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 27  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 28  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 29  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 30  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 31  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 32  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 33  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 34  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 35  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 36  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 37  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 38  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 39  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 40  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
#
#                                               geocode RightToReply  \
# 0       {'longitude': 0.27694, 'latitude': 50.769705}
# 1      {'longitude': 1.278721, 'latitude': 51.857536}
# 2       {'longitude': 1.15927, 'latitude': 51.789429}
# 3      {'longitude': 0.101446, 'latitude': 50.770724}
# 4       {'longitude': 0.10202, 'latitude': 50.770885}
# 5      {'longitude': 0.736349, 'latitude': 51.541448}
# 6    {'longitude': 0.7121671, 'latitude': 51.5350065}
# 7      {'longitude': 0.602364, 'latitude': 51.591515}
# 8   {'longitude': 0.146449998021126, 'latitude': 5...
# 9       {'longitude': 0.462307, 'latitude': 51.57005}
# 10     {'longitude': 0.169685, 'latitude': 51.284795}
# 11   {'longitude': 0.1864034, 'latitude': 51.3954686}
# 12  {'longitude': 0.19265740017645, 'latitude': 51...
# 13       {'longitude': 0.2983, 'latitude': 51.618135}
# 14     {'longitude': 0.220507, 'latitude': 51.561287}
# 15   {'longitude': 0.1070469, 'latitude': 51.4848146}
# 16   {'longitude': 0.0460971, 'latitude': 51.4273993}
# 17   {'longitude': 0.0888789, 'latitude': 51.4800266}
# 18   {'longitude': 0.1300921, 'latitude': 51.5515791}
# 19     {'longitude': 0.084452, 'latitude': 51.541715}
# 20     {'longitude': 0.081616, 'latitude': 51.539293}
# 21     {'longitude': 0.055764, 'latitude': 51.531385}
# 22     {'longitude': 0.074347, 'latitude': 51.551624}
# 23   {'longitude': 0.0725645, 'latitude': 51.5540755}
# 24     {'longitude': 0.077645, 'latitude': 51.562276}
# 25     {'longitude': 0.046878, 'latitude': 51.531936}
# 26      {'longitude': 0.050713, 'latitude': 51.53963}
# 27     {'longitude': 0.050334, 'latitude': 51.541156}
# 28      {'longitude': 0.021028, 'latitude': 51.52189}
# 29     {'longitude': 0.018342, 'latitude': 51.520147}
# 30     {'longitude': 0.037523, 'latitude': 51.541658}
# 31   {'longitude': 0.3659018, 'latitude': 51.8686712}
# 32     {'longitude': 0.031959, 'latitude': 51.543994}
# 33     {'longitude': 0.360846, 'latitude': 51.873055}
# 34     {'longitude': 0.004389, 'latitude': 51.538857}
# 35     {'longitude': 0.005407, 'latitude': 51.555782}
# 36     {'longitude': 0.009101, 'latitude': 51.568245}
# 37      {'longitude': 0.006248, 'latitude': 51.61912}
# 38  {'longitude': 0.207771003246307, 'latitude': 5...
# 39     {'longitude': 0.201087, 'latitude': 51.904039}
# 40      {'longitude': 0.240491, 'latitude': 52.02328}
#
#        Distance NewRatingPending  \
# 0   4613.888288            False
# 1   4617.965824            False
# 2   4619.656144            False
# 3   4620.437179            False
# 4   4620.421725            False
# 5   4625.565258            False
# 6   4626.200132            False
# 7   4632.276890            False
# 8   4633.934041            False
# 9   4636.552523            False
# 10  4636.703065            False
# 11  4640.152449            False
# 12  4642.935252            False
# 13  4644.277277            False
# 14  4645.006441            False
# 15  4646.327125            False
# 16  4646.448256             True
# 17  4646.814122            False
# 18  4647.937955            False
# 19  4649.237462            False
# 20  4649.251920            False
# 21  4649.903794            False
# 22  4649.968842            False
# 23  4650.123644            False
# 24  4650.239432            False
# 25  4650.247785            False
# 26  4650.389971            False
# 27  4650.459698            False
# 28  4650.822100            False
# 29  4650.856226            False
# 30  4650.944835            False
# 31  4651.099995            False
# 32  4651.233130            False
# 33  4651.444488            False
# 34  4652.049760            False
# 35  4652.632190            False
# 36  4652.953922             True
# 37  4654.920996            False
# 38  4656.798774            False
# 39  4658.344880            False
# 40  4661.334349            False
#
#                                                  meta  \
# 0   {'dataSource': None, 'extractDate': '0001-01-0...
# 1   {'dataSource': None, 'extractDate': '0001-01-0...
# 2   {'dataSource': None, 'extractDate': '0001-01-0...
# 3   {'dataSource': None, 'extractDate': '0001-01-0...
# 4   {'dataSource': None, 'extractDate': '0001-01-0...
# 5   {'dataSource': None, 'extractDate': '0001-01-0...
# 6   {'dataSource': None, 'extractDate': '0001-01-0...
# 7   {'dataSource': None, 'extractDate': '0001-01-0...
# 8   {'dataSource': None, 'extractDate': '0001-01-0...
# 9   {'dataSource': None, 'extractDate': '0001-01-0...
# 10  {'dataSource': None, 'extractDate': '0001-01-0...
# 11  {'dataSource': None, 'extractDate': '0001-01-0...
# 12  {'dataSource': None, 'extractDate': '0001-01-0...
# 13  {'dataSource': None, 'extractDate': '0001-01-0...
# 14  {'dataSource': None, 'extractDate': '0001-01-0...
# 15  {'dataSource': None, 'extractDate': '0001-01-0...
# 16  {'dataSource': None, 'extractDate': '0001-01-0...
# 17  {'dataSource': None, 'extractDate': '0001-01-0...
# 18  {'dataSource': None, 'extractDate': '0001-01-0...
# 19  {'dataSource': None, 'extractDate': '0001-01-0...
# 20  {'dataSource': None, 'extractDate': '0001-01-0...
# 21  {'dataSource': None, 'extractDate': '0001-01-0...
# 22  {'dataSource': None, 'extractDate': '0001-01-0...
# 23  {'dataSource': None, 'extractDate': '0001-01-0...
# 24  {'dataSource': None, 'extractDate': '0001-01-0...
# 25  {'dataSource': None, 'extractDate': '0001-01-0...
# 26  {'dataSource': None, 'extractDate': '0001-01-0...
# 27  {'dataSource': None, 'extractDate': '0001-01-0...
# 28  {'dataSource': None, 'extractDate': '0001-01-0...
# 29  {'dataSource': None, 'extractDate': '0001-01-0...
# 30  {'dataSource': None, 'extractDate': '0001-01-0...
# 31  {'dataSource': None, 'extractDate': '0001-01-0...
# 32  {'dataSource': None, 'extractDate': '0001-01-0...
# 33  {'dataSource': None, 'extractDate': '0001-01-0...
# 34  {'dataSource': None, 'extractDate': '0001-01-0...
# 35  {'dataSource': None, 'extractDate': '0001-01-0...
# 36  {'dataSource': None, 'extractDate': '0001-01-0...
# 37  {'dataSource': None, 'extractDate': '0001-01-0...
# 38  {'dataSource': None, 'extractDate': '0001-01-0...
# 39  {'dataSource': None, 'extractDate': '0001-01-0...
# 40  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                 links
# 0   [{'rel': 'self', 'href': 'https://api.ratings....
# 1   [{'rel': 'self', 'href': 'https://api.ratings....
# 2   [{'rel': 'self', 'href': 'https://api.ratings....
# 3   [{'rel': 'self', 'href': 'https://api.ratings....
# 4   [{'rel': 'self', 'href': 'https://api.ratings....
# 5   [{'rel': 'self', 'href': 'https://api.ratings....
# 6   [{'rel': 'self', 'href': 'https://api.ratings....
# 7   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 10  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 11  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 12  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 13  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 14  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 15  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 16  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 17  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 18  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 19  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 20  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 21  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 22  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 23  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 24  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 25  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 26  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 27  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 28  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 29  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 30  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 31  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 32  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 33  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 34  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 35  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 36  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 37  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 38  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 39  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 40  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [41 rows x 28 columns]

# %%
# Display the number of rows in the DataFrame
print(f"There are {len(df)} rows in the dataframe.")
# Out:
# There are 41 rows in the dataframe.

# %%
# Display the first 10 rows of the DataFrame
df[:10]
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  640a122f8262e151aa17f4fb   110681                  0
# 1  640a122f8262e151aa17f880   612039                  0
# 2  640a122f8262e151aa17fb82   730933                  0
# 3  640a122f8262e151aa17fd7a   172953                  0
# 4  640a122f8262e151aa17fd81   172735                  0
# 5  640a122f8262e151aa18071d   512854                  0
# 6  640a122f8262e151aa18093f  1537089                  0
# 7  640a12308262e151aa181e6b   155648                  0
# 8  640a12308262e151aa1822af  1012883                  0
# 9  640a12308262e151aa182abf   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000024532              Golden Palace
# 4             PI/000023858              Seaford Pizza
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3            Restaurant/Cafe/Canteen               1         5 South Street
# 4             Takeaway/sandwich shop            7844          4 High Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                       LocalAuthorityWebSite  \
# 0  http://www.eastbourne.gov.uk/foodratings
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4       http://www.lewes-eastbourne.gov.uk/
# 5                http://www.southend.gov.uk
# 6                http://www.southend.gov.uk
# 7                http://www.rochford.gov.uk
# 8              http://www.sevenoaks.gov.uk/
# 9                http://www.basildon.gov.uk
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
# 9                    ehs@basildon.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
#
#                                              geocode RightToReply  \
# 0      {'longitude': 0.27694, 'latitude': 50.769705}
# 1     {'longitude': 1.278721, 'latitude': 51.857536}
# 2      {'longitude': 1.15927, 'latitude': 51.789429}
# 3     {'longitude': 0.101446, 'latitude': 50.770724}
# 4      {'longitude': 0.10202, 'latitude': 50.770885}
# 5     {'longitude': 0.736349, 'latitude': 51.541448}
# 6   {'longitude': 0.7121671, 'latitude': 51.5350065}
# 7     {'longitude': 0.602364, 'latitude': 51.591515}
# 8  {'longitude': 0.146449998021126, 'latitude': 5...
# 9      {'longitude': 0.462307, 'latitude': 51.57005}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.437179            False
# 4  4620.421725            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {"$and" :[
    {"LocalAuthorityName": {"$regex":"London"}},
    {"RatingValue": {"$in":['4','5']}}
]}
results = establishments.find(query)
# Use count_documents to display the number of documents in the result
establishments.count_documents(query)
# Out:
# 33

# %%
# Display the first document in the results using pprint
pprint(results[0])
# Out:
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('640a122f8262e151aa180f16'),
#  'geocode': {'latitude': Decimal128('51.369321'),
#              'longitude': Decimal128('0.508551')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(results)
df
# Out:
#                          _id   FHRSID  ChangesByServerID  \
# 0   640a122f8262e151aa180f16   621707                  0
# 1   640a122f8262e151aa181237  1130836                  0
# 2   640a12308262e151aa181d87   293783                  0
# 3   640a12308262e151aa182b84   294474                  0
# 4   640a12308262e151aa182b8a  1315095                  0
# 5   640a12308262e151aa183297   294900                  0
# 6   640a12308262e151aa18539b   293756                  0
# 7   640a12308262e151aa185775   878523                  0
# 8   640a12308262e151aa18577d   293772                  0
# 9   640a12308262e151aa18577f   294606                  0
# 10  640a12308262e151aa185780   295107                  0
# 11  640a12308262e151aa185959   294616                  0
# 12  640a12308262e151aa18595a   294523                  0
# 13  640a12308262e151aa185c01  1427985                  0
# 14  640a12308262e151aa185e0f   934211                  0
# 15  640a12308262e151aa185e33   558640                  0
# 16  640a12308262e151aa185e34  1392440                  0
# 17  640a12308262e151aa185ff6  1498024                  0
# 18  640a12308262e151aa18603f  1090017                  0
# 19  640a12308262e151aa186041  1090023                  0
# 20  640a12308262e151aa186042  1090021                  0
# 21  640a12308262e151aa186043  1090022                  0
# 22  640a12308262e151aa186044  1090019                  0
# 23  640a12308262e151aa186046  1090018                  0
# 24  640a12308262e151aa186048  1090024                  0
# 25  640a12308262e151aa186049  1090016                  0
# 26  640a12308262e151aa18604b  1090026                  0
# 27  640a12308262e151aa18604c  1090028                  0
# 28  640a12308262e151aa18604d  1450220                  0
# 29  640a12308262e151aa18604e  1090020                  0
# 30  640a12308262e151aa186052  1090027                  0
# 31  640a12308262e151aa186054   293758                  0
# 32  640a12308262e151aa186056  1090025                  0
#
#    LocalAuthorityBusinessID                          BusinessName  \
# 0              PI/000025307                             Charlie's
# 1              PI/000034075               Mv City Cruises Erasmus
# 2              PI/000002614             Benfleet Motor Yacht Club
# 3              PI/000014647              Tilbury Seafarers Centre
# 4              PI/000036464  Coombs Catering t/a The Lock and Key
# 5              PI/000019066                            Mv Valulla
# 6              PI/000002538                         Tereza Joanne
# 7              PI/000029844                      Brick Lane Brews
# 8              PI/000002585         The Nuance Group (UK) Limited
# 9              PI/000016185                              WH Smith
# 10             PI/000020749                      City Bar & Grill
# 11             PI/000016269                            Caffè Nero
# 12             PI/000015222                            Jet Centre
# 13             PI/000037871                Mv Sunborn Yacht Hotel
# 14             PI/000030457                     Good Hotel London
# 15             PI/000024155             Wake Up Docklands Limited
# 16             PI/000037382                         La Nonna lina
# 17             PI/000038347                      MV Venus Clipper
# 18             PI/000033472                       MV Moon clipper
# 19             PI/000033479                    MV Jupiter clipper
# 20             PI/000033477                    MV Monsoon clipper
# 21             PI/000033478                     MV Meteor clipper
# 22             PI/000033475                    MV Tornado clipper
# 23             PI/000033473                    MV Mercury clipper
# 24             PI/000033480                     MV Galaxy clipper
# 25             PI/000033470                        MV Sun clipper
# 26             PI/000033482                     MV Aurora clipper
# 27             PI/000033484                    MV Neptune clipper
# 28             PI/000038259                       Canary Wharf 1V
# 29             PI/000033476                    MV Typhoon clipper
# 30             PI/000033483                    MV Cyclone clipper
# 31             PI/000002546                      Mv Storm Clipper
# 32             PI/000033481                  MV Hurricane clipper
#
#                          BusinessType  BusinessTypeID  \
# 0             Other catering premises            7841
# 1             Other catering premises            7841
# 2             Other catering premises            7841
# 3             Restaurant/Cafe/Canteen               1
# 4             Restaurant/Cafe/Canteen               1
# 5             Other catering premises            7841
# 6             Other catering premises            7841
# 7             Restaurant/Cafe/Canteen               1
# 8                   Retailers - other            4613
# 9                   Retailers - other            4613
# 10            Restaurant/Cafe/Canteen               1
# 11            Restaurant/Cafe/Canteen               1
# 12            Restaurant/Cafe/Canteen               1
# 13  Hotel/bed & breakfast/guest house            7842
# 14            Other catering premises            7841
# 15            Other catering premises            7841
# 16            Other catering premises            7841
# 17            Other catering premises            7841
# 18            Other catering premises            7841
# 19            Other catering premises            7841
# 20            Other catering premises            7841
# 21            Other catering premises            7841
# 22            Other catering premises            7841
# 23            Other catering premises            7841
# 24            Other catering premises            7841
# 25            Other catering premises            7841
# 26            Other catering premises            7841
# 27            Other catering premises            7841
# 28            Other catering premises            7841
# 29            Other catering premises            7841
# 30            Other catering premises            7841
# 31            Other catering premises            7841
# 32            Other catering premises            7841
#
#                                          AddressLine1  \
# 0          Oak Apple Farm Building 103 Sheernes Docks
# 1                                  Cherry Garden Pier
# 2                                          Ferry Road
# 3                           Tenants Row Tilbury Docks
# 4                                   Leslie Ford House
# 5   Reeds River Cruises LtdKings ReachRiver Thames...
# 6   Funcraft UK Ltd King George V Dock Woolwich Ma...
# 7                        Air side London City Airport
# 8                   Duty Free Shop Passenger Terminal
# 9                                 London City Airport
# 10                      London City Airport (Airside)
# 11       London City Airport Airside Departure Lounge
# 12                                London City Airport
# 13                                    Western Gateway
# 14                Western Gateway Royal Victoria Dock
# 15                 Western Beach Royal Victoria Docks
# 16                                          Dock Road
# 17                                 Trinity Buoy Wharf
# 18             Thames Clippers 3rd flr Clippers House
# 19     Thames Clippers Unit 12 The Riverside Building
# 20     Thames Clippers Unit 12 The Riverside Building
# 21     Thames Clippers Unit 12 The Riverside Building
# 22     Thames Clippers Unit 12 The Riverside Building
# 23             Thames Clippers 3rd flr Clippers House
# 24     Thames Clippers Unit 12 The Riverside Building
# 25             Thames Clippers 3rd flr Clippers House
# 26     Thames Clippers Unit 12 The Riverside Building
# 27     Thames Clippers Unit 12 The Riverside Building
# 28                                 Trinity Buoy Wharf
# 29     Thames Clippers Unit 12 The Riverside Building
# 30     Thames Clippers Unit 12 The Riverside Building
# 31     Thames Clippers Unit 12 The Riverside Building
# 32     Thames Clippers Unit 12 The Riverside Building
#
#                                     AddressLine2 AddressLine3  ...  \
# 0                                    Sheppy Kent               ...
# 1               Cherry Garden Street Rotherhithe     Charlton  ...
# 2                           South Benfleet Essex               ...
# 3                                  Tilbury Essex               ...
# 4                                        Tilbury     Charlton  ...
# 5                                         London               ...
# 6                                         London               ...
# 7                                         London               ...
# 8           London City AirportRoyal DocksLondon               ...
# 9                              Silvertown London               ...
# 10                                        London               ...
# 11                            Royal Docks London               ...
# 12                            Royal Docks London               ...
# 13                           Royal Victoria Dock               ...
# 14  Floating Platform next to Emirates Cable Car               ...
# 15                                        London     Charlton  ...
# 16                                        London     Charlton  ...
# 17                                 Orchard Place               ...
# 18       Orchard Place Trinity Buoy Wharf London               ...
# 19    64 Orchard Place Trinity Buoy Wharf London               ...
# 20    64 Orchard Place Trinity Buoy Wharf London               ...
# 21    64 Orchard Place Trinity Buoy Wharf London               ...
# 22    64 Orchard Place Trinity Buoy Wharf London               ...
# 23       Orchard Place Trinity Buoy Wharf London               ...
# 24    64 Orchard Place Trinity Buoy Wharf London               ...
# 25       Orchard Place Trinity Buoy Wharf London               ...
# 26    64 Orchard Place Trinity Buoy Wharf London               ...
# 27    64 Orchard Place Trinity Buoy Wharf London               ...
# 28                              64 Orchard Place               ...
# 29    64 Orchard Place Trinity Buoy Wharf London               ...
# 30    64 Orchard Place Trinity Buoy Wharf London               ...
# 31    64 Orchard Place Trinity Buoy Wharf London               ...
# 32    64 Orchard Place Trinity Buoy Wharf London               ...
#
#                                 LocalAuthorityWebSite  \
# 0   http://www.cityoflondon.gov.uk/Corporation/hom...
# 1   http://www.cityoflondon.gov.uk/Corporation/hom...
# 2   http://www.cityoflondon.gov.uk/Corporation/hom...
# 3   http://www.cityoflondon.gov.uk/Corporation/hom...
# 4   http://www.cityoflondon.gov.uk/Corporation/hom...
# 5   http://www.cityoflondon.gov.uk/Corporation/hom...
# 6   http://www.cityoflondon.gov.uk/Corporation/hom...
# 7   http://www.cityoflondon.gov.uk/Corporation/hom...
# 8   http://www.cityoflondon.gov.uk/Corporation/hom...
# 9   http://www.cityoflondon.gov.uk/Corporation/hom...
# 10  http://www.cityoflondon.gov.uk/Corporation/hom...
# 11  http://www.cityoflondon.gov.uk/Corporation/hom...
# 12  http://www.cityoflondon.gov.uk/Corporation/hom...
# 13  http://www.cityoflondon.gov.uk/Corporation/hom...
# 14  http://www.cityoflondon.gov.uk/Corporation/hom...
# 15  http://www.cityoflondon.gov.uk/Corporation/hom...
# 16  http://www.cityoflondon.gov.uk/Corporation/hom...
# 17  http://www.cityoflondon.gov.uk/Corporation/hom...
# 18  http://www.cityoflondon.gov.uk/Corporation/hom...
# 19  http://www.cityoflondon.gov.uk/Corporation/hom...
# 20  http://www.cityoflondon.gov.uk/Corporation/hom...
# 21  http://www.cityoflondon.gov.uk/Corporation/hom...
# 22  http://www.cityoflondon.gov.uk/Corporation/hom...
# 23  http://www.cityoflondon.gov.uk/Corporation/hom...
# 24  http://www.cityoflondon.gov.uk/Corporation/hom...
# 25  http://www.cityoflondon.gov.uk/Corporation/hom...
# 26  http://www.cityoflondon.gov.uk/Corporation/hom...
# 27  http://www.cityoflondon.gov.uk/Corporation/hom...
# 28  http://www.cityoflondon.gov.uk/Corporation/hom...
# 29  http://www.cityoflondon.gov.uk/Corporation/hom...
# 30  http://www.cityoflondon.gov.uk/Corporation/hom...
# 31  http://www.cityoflondon.gov.uk/Corporation/hom...
# 32  http://www.cityoflondon.gov.uk/Corporation/hom...
#
#               LocalAuthorityEmailAddress  \
# 0   publicprotection@cityoflondon.gov.uk
# 1   publicprotection@cityoflondon.gov.uk
# 2   publicprotection@cityoflondon.gov.uk
# 3   publicprotection@cityoflondon.gov.uk
# 4   publicprotection@cityoflondon.gov.uk
# 5   publicprotection@cityoflondon.gov.uk
# 6   publicprotection@cityoflondon.gov.uk
# 7   publicprotection@cityoflondon.gov.uk
# 8   publicprotection@cityoflondon.gov.uk
# 9   publicprotection@cityoflondon.gov.uk
# 10  publicprotection@cityoflondon.gov.uk
# 11  publicprotection@cityoflondon.gov.uk
# 12  publicprotection@cityoflondon.gov.uk
# 13  publicprotection@cityoflondon.gov.uk
# 14  publicprotection@cityoflondon.gov.uk
# 15  publicprotection@cityoflondon.gov.uk
# 16  publicprotection@cityoflondon.gov.uk
# 17  publicprotection@cityoflondon.gov.uk
# 18  publicprotection@cityoflondon.gov.uk
# 19  publicprotection@cityoflondon.gov.uk
# 20  publicprotection@cityoflondon.gov.uk
# 21  publicprotection@cityoflondon.gov.uk
# 22  publicprotection@cityoflondon.gov.uk
# 23  publicprotection@cityoflondon.gov.uk
# 24  publicprotection@cityoflondon.gov.uk
# 25  publicprotection@cityoflondon.gov.uk
# 26  publicprotection@cityoflondon.gov.uk
# 27  publicprotection@cityoflondon.gov.uk
# 28  publicprotection@cityoflondon.gov.uk
# 29  publicprotection@cityoflondon.gov.uk
# 30  publicprotection@cityoflondon.gov.uk
# 31  publicprotection@cityoflondon.gov.uk
# 32  publicprotection@cityoflondon.gov.uk
#
#                                                scores SchemeType  \
# 0   {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...       FHRS
# 1   {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 2   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 3   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 4   {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 5   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 6   {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 7   {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...       FHRS
# 8   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 9   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 10  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 11  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 12  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 13  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 14  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 15  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 16  {'Hygiene': 0, 'Structural': 10, 'ConfidenceIn...       FHRS
# 17  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 18  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 19  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 20  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 21  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 22  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 23  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 24  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 25  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 26  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 27  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 28  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 29  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 30  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 31  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 32  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
#
#                                               geocode RightToReply  \
# 0      {'longitude': 0.508551, 'latitude': 51.369321}
# 1   {'longitude': 0.249255999922752, 'latitude': 5...
# 2      {'longitude': 0.561954, 'latitude': 51.543831}
# 3      {'longitude': 0.346325, 'latitude': 51.464078}
# 4   {'longitude': 0.346336990594864, 'latitude': 5...
# 5      {'longitude': 0.287555, 'latitude': 51.504071}
# 6      {'longitude': 0.069286, 'latitude': 51.501121}
# 7      {'longitude': 0.048006, 'latitude': 51.503733}
# 8      {'longitude': 0.047966, 'latitude': 51.504112}
# 9   {'longitude': 0.0479655750095844, 'latitude': ...
# 10  {'longitude': 0.0479655750095844, 'latitude': ...
# 11     {'longitude': 0.040518, 'latitude': 51.504808}
# 12  {'longitude': 0.0405181497335434, 'latitude': ...
# 13      {'longitude': 0.027107, 'latitude': 51.50817}
# 14      {'longitude': 0.01792, 'latitude': 51.507681}
# 15     {'longitude': 0.015742, 'latitude': 51.505992}
# 16  {'longitude': 0.0157549995929003, 'latitude': ...
# 17  {'longitude': 0.00890800673629534, 'latitude':...
# 18  {'longitude': 0.0078159999102354, 'latitude': ...
# 19     {'longitude': 0.007816, 'latitude': 51.508259}
# 20     {'longitude': 0.007816, 'latitude': 51.508259}
# 21     {'longitude': 0.007816, 'latitude': 51.508259}
# 22     {'longitude': 0.007816, 'latitude': 51.508259}
# 23  {'longitude': 0.0078159999102354, 'latitude': ...
# 24     {'longitude': 0.007816, 'latitude': 51.508259}
# 25  {'longitude': 0.0078159999102354, 'latitude': ...
# 26     {'longitude': 0.007816, 'latitude': 51.508259}
# 27     {'longitude': 0.007816, 'latitude': 51.508259}
# 28     {'longitude': 0.007815, 'latitude': 51.508259}
# 29     {'longitude': 0.007816, 'latitude': 51.508259}
# 30     {'longitude': 0.007816, 'latitude': 51.508259}
# 31     {'longitude': 0.007816, 'latitude': 51.508259}
# 32     {'longitude': 0.007816, 'latitude': 51.508259}
#
#        Distance NewRatingPending  \
# 0   4627.439468            False
# 1   4627.873179            False
# 2   4631.968418            False
# 3   4636.847650            False
# 4   4636.846754            False
# 5   4640.460834            False
# 6   4648.301822            False
# 7   4649.173485            False
# 8   4649.188826            False
# 9   4649.188850            False
# 10  4649.188850            False
# 11  4649.485929            False
# 12  4649.485870            False
# 13  4650.098130            False
# 14  4650.415301            False
# 15  4650.432926            False
# 16  4650.432066            False
# 17  4650.747349            False
# 18  4650.805001            False
# 19  4650.805008            False
# 20  4650.805008            False
# 21  4650.805008            False
# 22  4650.805008            False
# 23  4650.805001            False
# 24  4650.805008            False
# 25  4650.805001            False
# 26  4650.805008            False
# 27  4650.805008            False
# 28  4650.805044            False
# 29  4650.805008            False
# 30  4650.805008            False
# 31  4650.805008            False
# 32  4650.805008            False
#
#                                                  meta  \
# 0   {'dataSource': None, 'extractDate': '0001-01-0...
# 1   {'dataSource': None, 'extractDate': '0001-01-0...
# 2   {'dataSource': None, 'extractDate': '0001-01-0...
# 3   {'dataSource': None, 'extractDate': '0001-01-0...
# 4   {'dataSource': None, 'extractDate': '0001-01-0...
# 5   {'dataSource': None, 'extractDate': '0001-01-0...
# 6   {'dataSource': None, 'extractDate': '0001-01-0...
# 7   {'dataSource': None, 'extractDate': '0001-01-0...
# 8   {'dataSource': None, 'extractDate': '0001-01-0...
# 9   {'dataSource': None, 'extractDate': '0001-01-0...
# 10  {'dataSource': None, 'extractDate': '0001-01-0...
# 11  {'dataSource': None, 'extractDate': '0001-01-0...
# 12  {'dataSource': None, 'extractDate': '0001-01-0...
# 13  {'dataSource': None, 'extractDate': '0001-01-0...
# 14  {'dataSource': None, 'extractDate': '0001-01-0...
# 15  {'dataSource': None, 'extractDate': '0001-01-0...
# 16  {'dataSource': None, 'extractDate': '0001-01-0...
# 17  {'dataSource': None, 'extractDate': '0001-01-0...
# 18  {'dataSource': None, 'extractDate': '0001-01-0...
# 19  {'dataSource': None, 'extractDate': '0001-01-0...
# 20  {'dataSource': None, 'extractDate': '0001-01-0...
# 21  {'dataSource': None, 'extractDate': '0001-01-0...
# 22  {'dataSource': None, 'extractDate': '0001-01-0...
# 23  {'dataSource': None, 'extractDate': '0001-01-0...
# 24  {'dataSource': None, 'extractDate': '0001-01-0...
# 25  {'dataSource': None, 'extractDate': '0001-01-0...
# 26  {'dataSource': None, 'extractDate': '0001-01-0...
# 27  {'dataSource': None, 'extractDate': '0001-01-0...
# 28  {'dataSource': None, 'extractDate': '0001-01-0...
# 29  {'dataSource': None, 'extractDate': '0001-01-0...
# 30  {'dataSource': None, 'extractDate': '0001-01-0...
# 31  {'dataSource': None, 'extractDate': '0001-01-0...
# 32  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                 links
# 0   [{'rel': 'self', 'href': 'https://api.ratings....
# 1   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 10  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 11  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 12  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 13  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 14  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 15  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 16  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 17  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 18  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 19  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 20  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 21  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 22  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 23  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 24  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 25  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 26  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 27  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 28  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 29  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 30  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 31  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 32  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [33 rows x 28 columns]

# %%
# Display the number of rows in the DataFrame
print(f"There are {len(df)} rows in the dataframe.")
# Out:
# There are 33 rows in the dataframe.

# %%
# Display the first 10 rows of the DataFrame
df[:10]
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  640a122f8262e151aa180f16   621707                  0
# 1  640a122f8262e151aa181237  1130836                  0
# 2  640a12308262e151aa181d87   293783                  0
# 3  640a12308262e151aa182b84   294474                  0
# 4  640a12308262e151aa182b8a  1315095                  0
# 5  640a12308262e151aa183297   294900                  0
# 6  640a12308262e151aa18539b   293756                  0
# 7  640a12308262e151aa185775   878523                  0
# 8  640a12308262e151aa18577d   293772                  0
# 9  640a12308262e151aa18577f   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000014647              Tilbury Seafarers Centre
# 4             PI/000036464  Coombs Catering t/a The Lock and Key
# 5             PI/000019066                            Mv Valulla
# 6             PI/000002538                         Tereza Joanne
# 7             PI/000029844                      Brick Lane Brews
# 8             PI/000002585         The Nuance Group (UK) Limited
# 9             PI/000016185                              WH Smith
#
#               BusinessType  BusinessTypeID  \
# 0  Other catering premises            7841
# 1  Other catering premises            7841
# 2  Other catering premises            7841
# 3  Restaurant/Cafe/Canteen               1
# 4  Restaurant/Cafe/Canteen               1
# 5  Other catering premises            7841
# 6  Other catering premises            7841
# 7  Restaurant/Cafe/Canteen               1
# 8        Retailers - other            4613
# 9        Retailers - other            4613
#
#                                         AddressLine1  \
# 0         Oak Apple Farm Building 103 Sheernes Docks
# 1                                 Cherry Garden Pier
# 2                                         Ferry Road
# 3                          Tenants Row Tilbury Docks
# 4                                  Leslie Ford House
# 5  Reeds River Cruises LtdKings ReachRiver Thames...
# 6  Funcraft UK Ltd King George V Dock Woolwich Ma...
# 7                       Air side London City Airport
# 8                  Duty Free Shop Passenger Terminal
# 9                                London City Airport
#
#                            AddressLine2 AddressLine3  ...  \
# 0                           Sheppy Kent               ...
# 1      Cherry Garden Street Rotherhithe     Charlton  ...
# 2                  South Benfleet Essex               ...
# 3                         Tilbury Essex               ...
# 4                               Tilbury     Charlton  ...
# 5                                London               ...
# 6                                London               ...
# 7                                London               ...
# 8  London City AirportRoyal DocksLondon               ...
# 9                     Silvertown London               ...
#
#                                LocalAuthorityWebSite  \
# 0  http://www.cityoflondon.gov.uk/Corporation/hom...
# 1  http://www.cityoflondon.gov.uk/Corporation/hom...
# 2  http://www.cityoflondon.gov.uk/Corporation/hom...
# 3  http://www.cityoflondon.gov.uk/Corporation/hom...
# 4  http://www.cityoflondon.gov.uk/Corporation/hom...
# 5  http://www.cityoflondon.gov.uk/Corporation/hom...
# 6  http://www.cityoflondon.gov.uk/Corporation/hom...
# 7  http://www.cityoflondon.gov.uk/Corporation/hom...
# 8  http://www.cityoflondon.gov.uk/Corporation/hom...
# 9  http://www.cityoflondon.gov.uk/Corporation/hom...
#
#              LocalAuthorityEmailAddress  \
# 0  publicprotection@cityoflondon.gov.uk
# 1  publicprotection@cityoflondon.gov.uk
# 2  publicprotection@cityoflondon.gov.uk
# 3  publicprotection@cityoflondon.gov.uk
# 4  publicprotection@cityoflondon.gov.uk
# 5  publicprotection@cityoflondon.gov.uk
# 6  publicprotection@cityoflondon.gov.uk
# 7  publicprotection@cityoflondon.gov.uk
# 8  publicprotection@cityoflondon.gov.uk
# 9  publicprotection@cityoflondon.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...       FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 5  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 6  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 7  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...       FHRS
# 8  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 9  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 0.508551, 'latitude': 51.369321}
# 1  {'longitude': 0.249255999922752, 'latitude': 5...
# 2     {'longitude': 0.561954, 'latitude': 51.543831}
# 3     {'longitude': 0.346325, 'latitude': 51.464078}
# 4  {'longitude': 0.346336990594864, 'latitude': 5...
# 5     {'longitude': 0.287555, 'latitude': 51.504071}
# 6     {'longitude': 0.069286, 'latitude': 51.501121}
# 7     {'longitude': 0.048006, 'latitude': 51.503733}
# 8     {'longitude': 0.047966, 'latitude': 51.504112}
# 9  {'longitude': 0.0479655750095844, 'latitude': ...
#
#       Distance NewRatingPending  \
# 0  4627.439468            False
# 1  4627.873179            False
# 2  4631.968418            False
# 3  4636.847650            False
# 4  4636.846754            False
# 5  4640.460834            False
# 6  4648.301822            False
# 7  4649.173485            False
# 8  4649.188826            False
# 9  4649.188850            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of '5', sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000

query = {"$and":[
    {"RatingValue":{"$eq":"5"}},
    {"$and":[
        {"geocode.latitude":{"$gte":latitude-degree_search}},
        {"geocode.latitude":{"$lte":latitude+degree_search}}
    ]},
    {"$and":[
        {"geocode.longitude":{"$gte":longitude-degree_search}},
        {"geocode.longitude":{"$lte":longitude+degree_search}}
    ]}
]}
sort = [("scores.Hygiene", 1)]

results = establishments.find(query).sort(sort).limit(5)

# %%
# Print the results
pprint(list(results))
# Out:
# [{'AddressLine1': 'Restaurant And Premises 107A Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Howe and Co Fish and Chips - Van 17',
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'ChangesByServerID': 0,
#   'Distance': 4646.95593107927,
#   'FHRSID': 1380578,
#   'LocalAuthorityBusinessID': '14425',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1SE',
#   'RatingDate': '2021-11-11T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('640a12308262e151aa184d4b'),
#   'geocode': {'latitude': Decimal128('51.4875335693359'),
#               'longitude': Decimal128('0.0925370007753372')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1380578',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Plumstead Manor School Old Mill Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Plumstead Manor Nursery',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4646.9740101340385,
#   'FHRSID': 695241,
#   'LocalAuthorityBusinessID': 'PI/000179088',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1QG',
#   'RatingDate': '2021-06-16T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('640a12308262e151aa184d73'),
#   'geocode': {'latitude': Decimal128('51.481517791748'),
#               'longitude': Decimal128('0.0859939977526665')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695241',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '17 Lakedale Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Lumbini Grocery Ltd T/A Al-Iman',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4646.975587048333,
#   'FHRSID': 909912,
#   'LocalAuthorityBusinessID': 'PI/000201100',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1PP',
#   'RatingDate': '2020-10-20T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('640a12308262e151aa184d6e'),
#   'geocode': {'latitude': Decimal128('51.4871632'),
#               'longitude': Decimal128('0.0916256')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/909912',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': '144 - 146 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Iceland',
#   'BusinessType': 'Retailers - supermarkets/hypermarkets',
#   'BusinessTypeID': 7840,
#   'ChangesByServerID': 0,
#   'Distance': 4646.946071297699,
#   'FHRSID': 695223,
#   'LocalAuthorityBusinessID': 'PI/000178842',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-11-13T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('640a12308262e151aa184d34'),
#   'geocode': {'latitude': Decimal128('51.4871482849121'),
#               'longitude': Decimal128('0.0924199968576431')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695223',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': '130 - 132 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Volunteer',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4646.965634598608,
#   'FHRSID': 694609,
#   'LocalAuthorityBusinessID': 'PI/000116619',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-08-05T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('640a12308262e151aa184d55'),
#   'geocode': {'latitude': Decimal128('51.4873437'),
#               'longitude': Decimal128('0.09208')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694609',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}]

# %%
# Convert result to Pandas DataFrame
# Results variable will not work a second time for some reason
# df = pd.DataFrame(result)
df = pd.DataFrame(establishments.find(query).sort(sort).limit(5))
df
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  640a12308262e151aa184d4b  1380578                  0
# 1  640a12308262e151aa184d73   695241                  0
# 2  640a12308262e151aa184d6e   909912                  0
# 3  640a12308262e151aa184d34   695223                  0
# 4  640a12308262e151aa184d55   694609                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0                    14425  Howe and Co Fish and Chips - Van 17
# 1             PI/000179088              Plumstead Manor Nursery
# 2             PI/000201100      Lumbini Grocery Ltd T/A Al-Iman
# 3             PI/000178842                              Iceland
# 4             PI/000116619                            Volunteer
#
#                             BusinessType  BusinessTypeID  \
# 0                         Mobile caterer            7846
# 1                        Caring Premises               5
# 2                      Retailers - other            4613
# 3  Retailers - supermarkets/hypermarkets            7840
# 4                      Pub/bar/nightclub            7843
#
#                                         AddressLine1 AddressLine2  \
# 0  Restaurant And Premises 107A Plumstead High St...
# 1               Plumstead Manor School Old Mill Road
# 2                                   17 Lakedale Road
# 3                    144 - 146 Plumstead High Street
# 4                    130 - 132 Plumstead High Street
#
#   AddressLine3  ...             LocalAuthorityWebSite  \
# 0    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 1    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 2    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 3    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 4    Plumstead  ...  http://www.royalgreenwich.gov.uk
#
#      LocalAuthorityEmailAddress  \
# 0  health@royalgreenwich.gov.uk
# 1  health@royalgreenwich.gov.uk
# 2  health@royalgreenwich.gov.uk
# 3  health@royalgreenwich.gov.uk
# 4  health@royalgreenwich.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 1  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
#
#                                              geocode RightToReply  \
# 0  {'longitude': 0.0925370007753372, 'latitude': ...
# 1  {'longitude': 0.0859939977526665, 'latitude': ...
# 2   {'longitude': 0.0916256, 'latitude': 51.4871632}
# 3  {'longitude': 0.0924199968576431, 'latitude': ...
# 4     {'longitude': 0.09208, 'latitude': 51.4873437}
#
#       Distance NewRatingPending  \
# 0  4646.955931            False
# 1  4646.974010            False
# 2  4646.975587            False
# 3  4646.946071            False
# 4  4646.965635            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [5 rows x 28 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
match_query = {'$match': {'scores.Hygiene': {"$eq":0}}}

# 2. Groups the matches by Local Authority
group_query = {'$group': {'_id': "$LocalAuthorityName", 'count':{'$sum':1}}}

# 3. Sorts the matches from highest to lowest
sort_values = {'$sort': { 'count': -1}}


pipeline = [match_query, group_query, sort_values]
results = list(establishments.aggregate(pipeline))

# Print the number of documents in the result
print("Number of countries in result: ", len(results))
# Out:
# Number of countries in result:  55

# %%
# Print the first 10 results
results[:10]
# Out:
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
len(df)
# Out:
# 55

# %%
# Display the first 10 rows of the DataFrame
df[:10]
# Out:
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
